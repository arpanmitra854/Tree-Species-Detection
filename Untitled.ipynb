# %%
# !pip install tensorflow matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\soumik\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: matplotlib in c:\users\soumik\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\soumik\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\soumik\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\soumik\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\soumik\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\soumik\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\soumik\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\soumik\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\soumik\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\soumik\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\soumik\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\soumik\anaconda3\lib\site-packages (1.26.4)

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\soumik\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\soumik\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\soumik\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\soumik\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\soumik\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\soumik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\soumik\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\soumik\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\soumik\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\soumik\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\soumik\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\soumik\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\soumik\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
import tensorflow as tf
print(tf.__version__)
import numpy as np
print("NumPy Version:", np.__version__)
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
# Out:
# 2.19.0
# NumPy Version: 1.26.4

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "Tree_Species_Dataset",
    shuffle=True,
)
# Out:
# Found 1454 files belonging to 30 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['amla',
#  'asopalav',
#  'babul',
#  'bamboo',
#  'banyan',
#  'bili',
#  'cactus',
#  'champa',
#  'coconut',
#  'garmalo',
#  'gulmohor',
#  'gunda',
#  'jamun',
#  'kanchan',
#  'kesudo',
#  'khajur',
#  'mango',
#  'motichanoti',
#  'neem',
#  'nilgiri',
#  'other',
#  'pilikaren',
#  'pipal',
#  'saptaparni',
#  'shirish',
#  'simlo',
#  'sitafal',
#  'sonmahor',
#  'sugarcane',
#  'vad']

# %%
import os
from PIL import Image, UnidentifiedImageError
import pandas as pd
import hashlib

# Initialize lists
image_paths, widths, heights, corrupted = [], [], [], []

# Root dataset directory
root_dir = "Tree_Species_Dataset"

# Loop through images
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    if not os.path.isdir(folder_path):
        continue
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        try:
            with Image.open(file_path) as img:
                w, h = img.size
                widths.append(w)
                heights.append(h)
                image_paths.append(file_path)
        except UnidentifiedImageError:
            corrupted.append(file_path)

# Create DataFrame of valid images
df_sizes = pd.DataFrame({
    "path": image_paths,
    "width": widths,
    "height": heights
})

# Check for very small and very large images
small_imgs = df_sizes[(df_sizes['width'] < 150) | (df_sizes['height'] < 150)]
large_imgs = df_sizes[(df_sizes['width'] > 1000) | (df_sizes['height'] > 2000)]

# Check for duplicate images (by hash)
def get_hash(file_path):
    with open(file_path, 'rb') as f:
        return hashlib.md5(f.read()).hexdigest()

df_sizes['hash'] = df_sizes['path'].apply(get_hash)
duplicate_imgs = df_sizes[df_sizes.duplicated('hash', keep=False)]

# Results
print(f" Total images checked: {len(df_sizes)}")
print(f" Corrupted images found: {len(corrupted)}")
print(f" Duplicate images found: {len(duplicate_imgs)}")
print(f" Very small images: {len(small_imgs)}")
print(f" Very large images: {len(large_imgs)}")
# Out:
#  Total images checked: 1454
#  Corrupted images found: 0
#  Duplicate images found: 0
#  Very small images: 0
#  Very large images: 0

# %%
import os
import pandas as pd

# Path to your dataset folder
repo_path = "Tree_Species_Dataset"

# Get list of class folders inside the dataset
class_dirs = [d for d in os.listdir(repo_path) if os.path.isdir(os.path.join(repo_path, d))]

# Count number of images in each class folder
class_counts = {
    cls: len(os.listdir(os.path.join(repo_path, cls)))
    for cls in class_dirs
}

# Convert to DataFrame
class_counts_df = pd.DataFrame.from_dict(class_counts, orient='index', columns=['Image Count'])

# Sort and show top 5 classes with most images
print(class_counts_df.sort_values('Image Count', ascending=False).head())

# Print shape: (number of classes, 1)
print("shape:", class_counts_df.shape)
# Out:
#            Image Count
# other              125
# sugarcane           50
# bamboo              50
# neem                50
# khajur              49
# shape: (30, 1)

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

def show_sample_images(repo_path, n=5):
    # Get all class directories
    class_dirs = [d for d in os.listdir(repo_path) if os.path.isdir(os.path.join(repo_path, d))]

    # Plot
    plt.figure(figsize=(15, 10))
    for i, class_dir in enumerate(class_dirs[:n]):
        class_path = os.path.join(repo_path, class_dir)
        img_files = os.listdir(class_path)
        
        # Skip if folder is empty
        if not img_files:
            continue

        # Pick the first image
        img_path = os.path.join(class_path, img_files[0])
        try:
            img = Image.open(img_path)
            plt.subplot(1, n, i + 1)
            plt.imshow(img)
            plt.title(class_dir)
            plt.axis('off')
        except:
            print(f"Error loading image: {img_path}")
            continue

    plt.tight_layout()
    plt.show()

# Example usage
repo_path = "Tree_Species_Dataset"
show_sample_images(repo_path, n=5)

# %%
import os
from PIL import Image
import pandas as pd

# Path to your dataset
repo_path = "Tree_Species_Dataset"

# Get all class directories
class_dirs = [d for d in os.listdir(repo_path) if os.path.isdir(os.path.join(repo_path, d))]

# Collect image sizes
image_shapes = []

for class_dir in class_dirs:
    class_path = os.path.join(repo_path, class_dir)
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        try:
            with Image.open(img_path) as img:
                width, height = img.size
                image_shapes.append((width, height))
        except:
            print(f"Corrupted or unreadable image: {img_path}")

# Create DataFrame
shapes_df = pd.DataFrame(image_shapes, columns=["Width", "Height"])

# Preview
print(shapes_df.head())
# Out:
#    Width  Height
# 0   1000    1000
# 1   1000     667
# 2    750     585
# 3    839     921
# 4    390    1247

# %%
# Summary statistics of image dimensions
summary_stats = shapes_df.describe()
print(summary_stats)
# Out:
#              Width       Height
# count  1454.000000  1454.000000
# mean    275.872765   239.044704
# std     117.507849   117.197342
# min     150.000000   150.000000
# 25%     225.000000   183.000000
# 50%     259.000000   198.000000
# 75%     275.000000   256.000000
# max    1000.000000  1247.000000

# %%
# Recalculate sizes
image_info = []

for class_dir in class_dirs:
    class_path = os.path.join(repo_path, class_dir)
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        try:
            with Image.open(img_path) as img:
                width, height = img.size
                image_info.append({
                    'path': img_path,
                    'width': width,
                    'height': height,
                    'class': class_dir
                })
        except:
            continue

df_sizes = pd.DataFrame(image_info)
print(df_sizes[['width', 'height']].describe())
# Out:
#              width       height
# count  1454.000000  1454.000000
# mean    275.872765   239.044704
# std     117.507849   117.197342
# min     150.000000   150.000000
# 25%     225.000000   183.000000
# 50%     259.000000   198.000000
# 75%     275.000000   256.000000
# max    1000.000000  1247.000000

# %%
IMAGE_SIZE=224
BATCH_SIZE=32
CHANNELS=3
EPOCHS=30

# %%
len(dataset)
# Out:
# 46

# %%
import matplotlib.pyplot as plt

for image_batch, label_batch in dataset.take(1):
    num_images = min(len(image_batch), 20)
    plt.figure(figsize=(14, 10))  # Increase figure size to make images larger

    for i in range(num_images):
        ax = plt.subplot(5, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.axis("off")  # Hide axes for a cleaner look

        # Add text above each image with adjusted positioning
        plt.text(0.5, 1.1, class_names[label_batch[i]], ha='center', va='bottom', transform=ax.transAxes, fontsize=10)

    plt.subplots_adjust(wspace=0.001, hspace=0.3)  # Adjust spacing between images if needed
    plt.show()

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import os
import glob

# Step 1: Load image paths and labels
dataset_dir = "Tree_Species_Dataset"  # 🔁 Replace with your dataset path

image_paths = []
labels = []

for class_name in os.listdir(dataset_dir):
    class_dir = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_dir):
        for img_file in glob.glob(os.path.join(class_dir, "*.jpg")):  # or "*.png"
            image_paths.append(img_file)
            labels.append(class_name)

# Step 2: Shuffle dataset
assert len(image_paths) == len(labels)
seed = 42
np.random.seed(seed)
indices = np.arange(len(image_paths))
np.random.shuffle(indices)

image_paths = np.array(image_paths)[indices]
labels = np.array(labels)[indices]

# Step 3: Split into train, val, test
total_size = len(image_paths)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size

train_paths = image_paths[:train_size]
train_labels = labels[:train_size]

val_paths = image_paths[train_size:train_size + val_size]
val_labels = labels[train_size:train_size + val_size]

test_paths = image_paths[train_size + val_size:]
test_labels = labels[train_size + val_size:]

# Step 4: Convert string labels to integer indices
label_to_index = {name: i for i, name in enumerate(sorted(set(labels)))}
train_labels = [label_to_index[label] for label in train_labels]
val_labels = [label_to_index[label] for label in val_labels]
test_labels = [label_to_index[label] for label in test_labels]

# Step 5: Image settings
img_size = (224, 224)
batch_size = 32

# Step 6: Load and preprocess images
def load_and_preprocess_image(path, label):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, img_size)
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def prepare_dataset(paths, labels):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    ds = ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

# Step 7: Create datasets
train_ds = prepare_dataset(train_paths, train_labels)
val_ds = prepare_dataset(val_paths, val_labels)
test_ds = prepare_dataset(test_paths, test_labels)

# Step 8: Print dataset info
print(f"Total images: {total_size}")
print(f"Train size: {len(train_paths)}")
print(f"Val size: {len(val_paths)}")
print(f"Test size: {len(test_paths)}")
print(f"Label mapping: {label_to_index}")
# Out:
# Total images: 688
# Train size: 550
# Val size: 68
# Test size: 70
# Label mapping: {'amla': 0, 'asopalav': 1, 'babul': 2, 'bili': 3, 'champa': 4, 'coconut': 5, 'garmalo': 6, 'gulmohor': 7, 'gunda': 8, 'jamun': 9, 'kanchan': 10, 'khajur': 11, 'mango': 12, 'motichanoti': 13, 'neem': 14, 'nilgiri': 15, 'other': 16, 'pilikaren': 17, 'pipal': 18, 'saptaparni': 19, 'shirish': 20}

# %%
len(train_ds)
# Out:
# 18

# %%
len(val_ds)
# Out:
# 3

# %%
len(test_ds)
# Out:
# 3

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0 / 255)
])

# %%
import tensorflow as tf
from tensorflow.keras import layers

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=AUTOTUNE)

val_ds = val_ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)
test_ds = test_ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)

# %%
num_classes=30

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Unfreeze the base model (or partial)
base_model.trainable = True

# Optional: freeze the first N layers, unfreeze the rest
for layer in base_model.layers[:100]:
    layer.trainable = False

# Custom model on top
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')  # Change num_classes accordingly
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_5           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 30)                  │           1,950 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,432,158 (9.28 MB)
#  Trainable params: 2,035,614 (7.77 MB)
#  Non-trainable params: 396,544 (1.51 MB)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(learning_rate=0.0001),  # low LR since we're fine-tuning
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30
)
# Out:
# Epoch 1/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.0311 - loss: 3.4753 - val_accuracy: 0.0276 - val_loss: 3.5704
# Epoch 2/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.0641 - loss: 3.3847 - val_accuracy: 0.0207 - val_loss: 3.5237
# Epoch 3/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.0804 - loss: 3.3563 - val_accuracy: 0.0207 - val_loss: 3.5109
# Epoch 4/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.0967 - loss: 3.3363 - val_accuracy: 0.0207 - val_loss: 3.4796
# Epoch 5/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.0924 - loss: 3.3273 - val_accuracy: 0.0207 - val_loss: 3.4758
# Epoch 6/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.0900 - loss: 3.3076 - val_accuracy: 0.0207 - val_loss: 3.4619
# Epoch 7/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.1070 - loss: 3.2515 - val_accuracy: 0.0276 - val_loss: 3.6020
# Epoch 8/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.1089 - loss: 3.2279 - val_accuracy: 0.0414 - val_loss: 3.4690
# Epoch 9/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.1333 - loss: 3.1941 - val_accuracy: 0.0414 - val_loss: 3.4721
# Epoch 10/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1110 - loss: 3.2205 - val_accuracy: 0.0138 - val_loss: 3.4467
# Epoch 11/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.1185 - loss: 3.2095 - val_accuracy: 0.0138 - val_loss: 3.5187
# Epoch 12/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.1165 - loss: 3.2061 - val_accuracy: 0.0828 - val_loss: 3.6484
# Epoch 13/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.1345 - loss: 3.1528 - val_accuracy: 0.0207 - val_loss: 3.5469
# Epoch 14/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.1322 - loss: 3.1305 - val_accuracy: 0.0276 - val_loss: 3.5787
# Epoch 15/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.1296 - loss: 3.1356 - val_accuracy: 0.0828 - val_loss: 3.4879
# Epoch 16/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.1229 - loss: 3.1362 - val_accuracy: 0.0828 - val_loss: 3.6347
# Epoch 17/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.1232 - loss: 3.1113 - val_accuracy: 0.0828 - val_loss: 3.5919
# Epoch 18/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.1359 - loss: 3.1110 - val_accuracy: 0.0828 - val_loss: 3.7598
# Epoch 19/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.1273 - loss: 3.1428 - val_accuracy: 0.0828 - val_loss: 4.0352
# Epoch 20/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.1281 - loss: 3.1330 - val_accuracy: 0.0828 - val_loss: 3.9554
# Epoch 21/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.1280 - loss: 3.0954 - val_accuracy: 0.0828 - val_loss: 3.8263
# Epoch 22/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.1350 - loss: 3.1188 - val_accuracy: 0.0828 - val_loss: 3.7085
# Epoch 23/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.1466 - loss: 3.0769 - val_accuracy: 0.0828 - val_loss: 3.5967
# Epoch 24/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.1565 - loss: 3.0522 - val_accuracy: 0.0828 - val_loss: 3.5723
# Epoch 25/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.1480 - loss: 3.0015 - val_accuracy: 0.0828 - val_loss: 3.5618
# Epoch 26/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.1505 - loss: 3.0331 - val_accuracy: 0.0828 - val_loss: 3.6356
# Epoch 27/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.1595 - loss: 3.0086 - val_accuracy: 0.0828 - val_loss: 3.6539
# Epoch 28/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.1676 - loss: 3.0133 - val_accuracy: 0.0828 - val_loss: 3.5119
# Epoch 29/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.1766 - loss: 2.9545 - val_accuracy: 0.0828 - val_loss: 3.4784
# Epoch 30/30
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.1520 - loss: 3.0107 - val_accuracy: 0.0828 - val_loss: 3.7313

# %%
scores=model.evaluate(test_ds)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 693ms/step - accuracy: 0.1016 - loss: 3.6089

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
import matplotlib.pyplot as plt

# Extract metrics
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Create subplots with reduced figure size
plt.figure(figsize=(10, 4))  # Adjusted the width and height

# Plot accuracy
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.plot(epochs, acc, label='Training Accuracy', marker='o')
plt.plot(epochs, val_acc, label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(epochs, loss, label='Training Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %%
import os

def save_model_versioned(model, folder_path='../Models', base_name='model', extension='.keras'):
    # Ensure the folder exists
    os.makedirs(folder_path, exist_ok=True)

    # Get the list of existing model files in the specified folder
    existing_models = [f for f in os.listdir(folder_path) if f.startswith(base_name) and f.endswith(extension)]

    # Determine the next model version number
    if existing_models:
        # Extract the version number from existing filenames
        versions = [int(f[len(base_name):-len(extension)]) for f in existing_models if f[len(base_name):-len(extension)].isdigit()]
        next_version = max(versions) + 1
    else:
        next_version = 1  # Start with version 1 if no models exist

    # Create the new filename
    new_model_name = os.path.join(folder_path, f"{base_name}{next_version}{extension}")

    # Save the model
    model.save(new_model_name)
    print(f"Model saved as: {new_model_name}")

# Example usage before training
# Assuming you have already trained your model:
# model.fit(...)  # Your training code goes here

# Save the model with versioning after training
save_model_versioned(model, folder_path='../Models', base_name='Model', extension='.keras')
# Out:
# Model saved as: ../Models\Model1.keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define parameters
IMG_HEIGHT = IMAGE_SIZE
IMG_WIDTH = IMAGE_SIZE
BATCH_SIZE = BATCH_SIZE

# Augmentation and rescaling
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

train_gen = datagen.flow_from_directory(
    repo_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    repo_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1177 images belonging to 30 classes.
# Found 277 images belonging to 30 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

base_model = EfficientNetB0(include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), weights='imagenet')
base_model.trainable = False  # Freeze base model

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(train_gen.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_6           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 30)                  │           3,870 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,217,409 (16.09 MB)
#  Trainable params: 167,838 (655.62 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
EPOCHS = 10

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS
)
# Out:
# C:\Users\SOUMIK\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step - accuracy: 0.0516 - loss: 3.4373 - val_accuracy: 0.0903 - val_loss: 3.3853
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.0802 - loss: 3.3996 - val_accuracy: 0.0903 - val_loss: 3.3817
# Epoch 3/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.1008 - loss: 3.3889 - val_accuracy: 0.0903 - val_loss: 3.3899
# Epoch 4/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.0854 - loss: 3.3859 - val_accuracy: 0.0903 - val_loss: 3.3797
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.0739 - loss: 3.3982 - val_accuracy: 0.0903 - val_loss: 3.3843
# Epoch 6/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.0834 - loss: 3.3854 - val_accuracy: 0.0903 - val_loss: 3.3789
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.0833 - loss: 3.3897 - val_accuracy: 0.0903 - val_loss: 3.3781
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.0812 - loss: 3.3819 - val_accuracy: 0.0903 - val_loss: 3.3738
# Epoch 9/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.0881 - loss: 3.3845 - val_accuracy: 0.0903 - val_loss: 3.3722
# Epoch 10/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.0858 - loss: 3.3763 - val_accuracy: 0.0903 - val_loss: 3.3748

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
import matplotlib.pyplot as plt

# Extract metrics
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Create subplots with reduced figure size
plt.figure(figsize=(10, 4))  # Adjusted the width and height

# Plot accuracy
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.plot(epochs, acc, label='Training Accuracy', marker='o')
plt.plot(epochs, val_acc, label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(epochs, loss, label='Training Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %%
import os

# Folder path where the model will be saved
save_dir = "Model_H5"

# Create the folder if it does not exist
os.makedirs(save_dir, exist_ok=True)

# Define the full path to save the model
model_path = os.path.join(save_dir, "my_model.h5")

# Save the model
model.save(model_path)

print(f"Model saved to: {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to: Model_H5\my_model.h5

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image properties
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Data generators
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = datagen.flow_from_directory(
    repo_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    repo_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Number of output classes
num_classes = train_generator.num_classes

# Build a basic CNN model
model_cnn = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])
# Out:
# Found 1177 images belonging to 30 classes.
# Found 277 images belonging to 30 classes.
# C:\Users\SOUMIK\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_cnn.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Train the model
EPOCHS = 10
history_cnn = model_cnn.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)
# Out:
# Epoch 1/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 101s 3s/step - accuracy: 0.0535 - loss: 4.2552 - val_accuracy: 0.0903 - val_loss: 3.3712
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.0962 - loss: 3.3515 - val_accuracy: 0.0903 - val_loss: 3.2390
# Epoch 3/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.0875 - loss: 3.2391 - val_accuracy: 0.1119 - val_loss: 3.1315
# Epoch 4/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.1060 - loss: 3.1503 - val_accuracy: 0.1336 - val_loss: 3.0438
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - accuracy: 0.1325 - loss: 3.1222 - val_accuracy: 0.1480 - val_loss: 2.9810
# Epoch 6/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.1633 - loss: 3.0462 - val_accuracy: 0.1625 - val_loss: 2.9726
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.1624 - loss: 3.0569 - val_accuracy: 0.2202 - val_loss: 2.8738
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.1813 - loss: 2.9133 - val_accuracy: 0.2274 - val_loss: 2.8664
# Epoch 9/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 0.2334 - loss: 2.8006 - val_accuracy: 0.2419 - val_loss: 2.8267
# Epoch 10/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.2536 - loss: 2.7598 - val_accuracy: 0.2924 - val_loss: 2.6480

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
import matplotlib.pyplot as plt

# Extract metrics
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Create subplots with reduced figure size
plt.figure(figsize=(10, 4))  # Adjusted the width and height

# Plot accuracy
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.plot(epochs, acc, label='Training Accuracy', marker='o')
plt.plot(epochs, val_acc, label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(epochs, loss, label='Training Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %%
import os

# Folder path where the model will be saved
save_dir = "Model_H5"

# Create the folder if it does not exist
os.makedirs(save_dir, exist_ok=True)

# Define the full path to save the model
model_path = os.path.join(save_dir, "basic_cnn_tree_species.h5")

# Save the model
model.save(model_path)

print(f"Model saved to: {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to: Model_H5\basic_cnn_tree_species.h5

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(30, activation='softmax')  # For 30 classes
])

model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_generator, validation_data=val_generator, epochs=25)
# Out:
# Epoch 1/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 139s 3s/step - accuracy: 0.0525 - loss: 5.2985 - val_accuracy: 0.0325 - val_loss: 9.9597
# Epoch 2/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 122s 3s/step - accuracy: 0.0946 - loss: 3.2948 - val_accuracy: 0.0325 - val_loss: 17.3517
# Epoch 3/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - accuracy: 0.1222 - loss: 3.1704 - val_accuracy: 0.0325 - val_loss: 21.0383
# Epoch 4/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 122s 3s/step - accuracy: 0.1351 - loss: 3.1639 - val_accuracy: 0.0325 - val_loss: 21.1604
# Epoch 5/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 122s 3s/step - accuracy: 0.1377 - loss: 3.1003 - val_accuracy: 0.0469 - val_loss: 22.3530
# Epoch 6/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - accuracy: 0.1513 - loss: 3.1146 - val_accuracy: 0.0505 - val_loss: 21.9452
# Epoch 7/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.1506 - loss: 3.0603 - val_accuracy: 0.0397 - val_loss: 20.8378
# Epoch 8/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.1671 - loss: 2.9834 - val_accuracy: 0.0903 - val_loss: 17.0674
# Epoch 9/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.1723 - loss: 2.9987 - val_accuracy: 0.0939 - val_loss: 15.7051
# Epoch 10/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.2063 - loss: 2.8964 - val_accuracy: 0.1119 - val_loss: 11.3234
# Epoch 11/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - accuracy: 0.2073 - loss: 2.9512 - val_accuracy: 0.1155 - val_loss: 8.6967
# Epoch 12/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.1888 - loss: 2.9145 - val_accuracy: 0.1047 - val_loss: 7.6496
# Epoch 13/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.2179 - loss: 2.8221 - val_accuracy: 0.1336 - val_loss: 5.4520
# Epoch 14/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - accuracy: 0.2133 - loss: 2.9216 - val_accuracy: 0.1588 - val_loss: 4.2598
# Epoch 15/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 129s 3s/step - accuracy: 0.2207 - loss: 2.8544 - val_accuracy: 0.1877 - val_loss: 3.4388
# Epoch 16/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - accuracy: 0.2153 - loss: 2.8403 - val_accuracy: 0.2166 - val_loss: 3.4473
# Epoch 17/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - accuracy: 0.2179 - loss: 2.8439 - val_accuracy: 0.2130 - val_loss: 3.4079
# Epoch 18/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - accuracy: 0.2081 - loss: 2.8324 - val_accuracy: 0.2310 - val_loss: 3.2133
# Epoch 19/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 114s 3s/step - accuracy: 0.2529 - loss: 2.7197 - val_accuracy: 0.2130 - val_loss: 3.1243
# Epoch 20/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - accuracy: 0.2228 - loss: 2.8116 - val_accuracy: 0.2347 - val_loss: 3.0799
# Epoch 21/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - accuracy: 0.2552 - loss: 2.7723 - val_accuracy: 0.2274 - val_loss: 3.0335
# Epoch 22/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step - accuracy: 0.2432 - loss: 2.6924 - val_accuracy: 0.2599 - val_loss: 3.1265
# Epoch 23/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 120s 3s/step - accuracy: 0.2622 - loss: 2.6474 - val_accuracy: 0.2599 - val_loss: 3.0036
# Epoch 24/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 118s 3s/step - accuracy: 0.2558 - loss: 2.6502 - val_accuracy: 0.2671 - val_loss: 2.9186
# Epoch 25/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 143s 3s/step - accuracy: 0.2779 - loss: 2.6084 - val_accuracy: 0.2816 - val_loss: 2.8959

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
import matplotlib.pyplot as plt

# Extract metrics
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Create subplots with reduced figure size
plt.figure(figsize=(10, 4))  # Adjusted the width and height

# Plot accuracy
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.plot(epochs, acc, label='Training Accuracy', marker='o')
plt.plot(epochs, val_acc, label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(epochs, loss, label='Training Loss', marker='o')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %%
import os

# Folder path where the model will be saved
save_dir = "Model_H5"

# Create the folder if it does not exist
os.makedirs(save_dir, exist_ok=True)

# Define the full path to save the model
model_path = os.path.join(save_dir, "improved_cnn_model.h5")

# Save the model
model.save(model_path)

print(f"Model saved to: {model_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to: Model_H5\improved_cnn_model.h5
